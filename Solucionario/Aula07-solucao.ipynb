# %% [markdown]
# <img src="https://imgur.com/XXT7Dbd.png" style="float:center;">

# %% [markdown]
# # <font color=#005757>Solução do Exercício Final</font>
#
# Considere esse exercício como um grande projeto de limpeza, exploração e análise de dados. Para isso iremos trabalhar com os dados da qualidade do ar de Fortaleza nos mês de janeiro e fevereiro de 2024. Siga cada etapa com calma.

# %% [markdown]
# **1) importe o pandas**

# %%
import pandas as pd

# %% [markdown]
# **2) Leia o arquivo `qualidade-do-ar-fortaleza.xlsx` onde cada planilha desse arquivo (jan2024 e fev2024) deve ser inserido em uma variável diferente (use `sheet_name` para acessar a planilha). Chame essas variáveis de `janeirio` e `fevereiro`.**

# %%
janeiro = pd.read_excel("../Dados/qualidade-do-ar-fortaleza.xlsx", sheet_name="jan2024", )
fevereiro = pd.read_excel("../Dados/qualidade-do-ar-fortaleza.xlsx", sheet_name="fev2024")

# %% [markdown]
# **3) Cheque as informações de cada dataframe**

# %%
janeiro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MÊS                          748 non-null    object
#  1   Óxido de Enxofre             702 non-null    float64
#  2   Óxido Nítrico                719 non-null    float64
#  3   Dióxido de Nitrogênio        718 non-null    float64
#  4   Óxidos de Nitrogênio         719 non-null    float64
#  5   Ozônio                       719 non-null    float64
#  6   Material Particulado <10µm   720 non-null    float64
#  7   Material Particulado <2,5µm  719 non-null    float64
#  8   Monóxido de carbono          720 non-null    float64
#  9   VelVento (m/s)               700 non-null    float64
#  10  DirVento (°)                 700 non-null    float64
#  11  T-PM10 (°C)                  722 non-null    float64
#  12  UR (%)                       700 non-null    float64
#  13  Press (mbar)                 700 non-null    float64
#  14  RadSol (W/m²)                699 non-null    float64
#  15  Chuva                        699 non-null    float64
#  16  chuva 24h                    31 non-null     float64
# dtypes: float64(16), object(1)
# memory usage: 99.6+ KB

# %%
fevereiro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MÊS                          700 non-null    object
#  1   Óxido de Enxofre             626 non-null    float64
#  2   Óxido Nítrico                646 non-null    float64
#  3   Dióxido de Nitrogênio        646 non-null    float64
#  4   Óxidos de Nitrogênio         646 non-null    float64
#  5   Ozônio                       647 non-null    float64
#  6   Material Particulado <10µm   648 non-null    float64
#  7   Material Particulado <2,5µm  648 non-null    float64
#  8   Monóxido de carbono          588 non-null    float64
#  9   VelVento (m/s)               650 non-null    float64
#  10  DirVento (°)                 650 non-null    float64
#  11  T-PM10 (°C)                  650 non-null    float64
#  12  UR (%)                       650 non-null    float64
#  13  Press (mbar)                 650 non-null    float64
#  14  RadSol (W/m²)                649 non-null    float64
#  15  Chuva                        649 non-null    float64
#  16  chuva 24h                    31 non-null     float64
# dtypes: float64(16), object(1)
# memory usage: 99.6+ KB

# %% [markdown]
# **4) Cheque o head dos dataframes**

# %%
janeiro.head()
# Out:
#                 MÊS  Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# 0  01/01/2024 00:00              10.0            1.0                    8.0
# 1  01/01/2024 01:00               7.0            1.0                    8.0
# 2  01/01/2024 02:00               3.0            2.0                   10.0
# 3  01/01/2024 03:00               4.0            2.0                   10.0
# 4  01/01/2024 04:00               3.0            1.0                    6.0
#
#    Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# 0                   9.0    21.0                        31.0
# 1                  10.0    20.0                        33.0
# 2                  12.0    18.0                        38.0
# 3                  13.0    15.0                        25.0
# 4                   7.0    46.0                        21.0
#
#    Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# 0                         18.0                  0.3             1.5
# 1                         22.0                  0.4             0.9
# 2                         15.0                  0.4             0.9
# 3                         20.0                  0.4             0.5
# 4                         18.0                  0.2             1.2
#
#    DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  Chuva  \
# 0           8.8         27.5    81.2        1003.1            0.0    0.0
# 1         342.9         27.4    82.6        1002.9            0.0    0.0
# 2           3.8         27.5    83.3        1002.2            0.0    0.2
# 3         308.9         27.0    88.8        1002.0            0.0    0.0
# 4          81.5         24.8    89.4        1002.1            0.0   29.4
#
#    chuva 24h
# 0       41.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
fevereiro.head()
# Out:
#                 MÊS  Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# 0  01/02/2024 00:00               6.0            0.0                    2.0
# 1  01/02/2024 01:00               5.0            0.0                    2.0
# 2  01/02/2024 02:00               6.0            0.0                    1.0
# 3  01/02/2024 03:00               6.0            0.0                    1.0
# 4  01/02/2024 04:00               7.0            0.0                    2.0
#
#    Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# 0                   3.0    44.0                        29.0
# 1                   2.0    45.0                        30.0
# 2                   2.0    47.0                        29.0
# 3                   2.0    47.0                        28.0
# 4                   2.0    48.0                        27.0
#
#    Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# 0                         19.0                  0.2             2.4
# 1                         15.0                  0.2             2.6
# 2                         16.0                  0.2             2.5
# 3                         16.0                  0.2             2.2
# 4                         12.0                  0.2             2.2
#
#    DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  Chuva  \
# 0          98.0         28.2    76.7        1003.3            0.0    0.0
# 1          98.4         28.1    75.2        1002.7            0.0    0.0
# 2         102.0         28.0    74.8        1002.2            0.0    0.0
# 3         102.2         28.0    75.4        1002.2            0.0    0.0
# 4          96.8         27.9    74.9        1002.2            0.0    0.0
#
#    chuva 24h
# 0        0.4
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# **4) Faça as seguintes limpezas em cada um dos dois DataFrames:**
#
# - Remova os valores `NaN` APENAS da coluna `MÊS`.
#
# - Remova as últimas 4 linhas.
#
# - Resete o índice (não esqueça de fazer `drop=True`).
#
# - Save todas as modificações nas variáveis `janeiro_v1` e `fevereiro_v1`

# %%
# Removendo os valores NaN da coluna MÊS
janeiro_v1 = janeiro.dropna(subset=["MÊS"])

# Removendo as últimas 4 linhas
janeiro_v1 = janeiro_v1.drop(janeiro_v1.index[-4:])

# Resetando o índice
janeiro_v1 = janeiro_v1.reset_index(drop=True)

# Como janeiro_v1 deve parecer
janeiro_v1
# Out:
#                   MÊS  Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# 0    01/01/2024 00:00              10.0            1.0                    8.0
# 1    01/01/2024 01:00               7.0            1.0                    8.0
# 2    01/01/2024 02:00               3.0            2.0                   10.0
# 3    01/01/2024 03:00               4.0            2.0                   10.0
# 4    01/01/2024 04:00               3.0            1.0                    6.0
# ..                ...               ...            ...                    ...
# 739  31/01/2024 19:00               7.0            1.0                    6.0
# 740  31/01/2024 20:00               5.0            1.0                    4.0
# 741  31/01/2024 21:00               5.0            0.0                    4.0
# 742  31/01/2024 22:00               6.0            0.0                    3.0
# 743  31/01/2024 23:00               7.0            0.0                    2.0
#
#      Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# 0                     9.0    21.0                        31.0
# 1                    10.0    20.0                        33.0
# 2                    12.0    18.0                        38.0
# 3                    13.0    15.0                        25.0
# 4                     7.0    46.0                        21.0
# ..                    ...     ...                         ...
# 739                   7.0    39.0                        37.0
# 740                   5.0    43.0                        37.0
# 741                   4.0    42.0                        27.0
# 742                   3.0    40.0                        29.0
# 743                   3.0    41.0                        25.0
#
#      Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# 0                           18.0                  0.3             1.5
# 1                           22.0                  0.4             0.9
# 2                           15.0                  0.4             0.9
# 3                           20.0                  0.4             0.5
# 4                           18.0                  0.2             1.2
# ..                           ...                  ...             ...
# 739                         17.0                  0.4             2.4
# 740                         15.0                  0.3             2.8
# 741                         11.0                  0.3             2.4
# 742                         11.0                  0.2             2.6
# 743                         17.0                  0.2             2.7
#
#      DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  Chuva  \
# 0             8.8         27.5    81.2        1003.1            0.0    0.0
# 1           342.9         27.4    82.6        1002.9            0.0    0.0
# 2             3.8         27.5    83.3        1002.2            0.0    0.2
# 3           308.9         27.0    88.8        1002.0            0.0    0.0
# 4            81.5         24.8    89.4        1002.1            0.0   29.4
# ..            ...          ...     ...           ...            ...    ...
# 739          85.2         28.4    76.3        1001.9            0.0    0.0
# 740          79.1         28.3    76.1        1002.6            0.0    0.0
# 741          85.0         28.2    76.6        1003.2            0.0    0.0
# 742          85.2         28.3    74.6        1003.4            0.0    0.0
# 743          84.3         28.2    76.9        1003.5            0.0    0.0
#
#      chuva 24h
# 0         41.0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 739        NaN
# 740        NaN
# 741        NaN
# 742        NaN
# 743        NaN
#
# [744 rows x 17 columns]

# %%
# Mesma coisa para fevereiro 
fevereiro_v1 = fevereiro.dropna(subset=["MÊS"])
fevereiro_v1 = fevereiro_v1.drop(fevereiro_v1.index[-4:])
fevereiro_v1 = fevereiro_v1.reset_index(drop=True)

# Como fevereiro_v1 deve parecer
fevereiro_v1
# Out:
#                   MÊS  Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# 0    01/02/2024 00:00               6.0            0.0                    2.0
# 1    01/02/2024 01:00               5.0            0.0                    2.0
# 2    01/02/2024 02:00               6.0            0.0                    1.0
# 3    01/02/2024 03:00               6.0            0.0                    1.0
# 4    01/02/2024 04:00               7.0            0.0                    2.0
# ..                ...               ...            ...                    ...
# 691  29/02/2024 19:00               NaN            NaN                    NaN
# 692  29/02/2024 20:00               NaN            NaN                    NaN
# 693  29/02/2024 21:00               NaN            NaN                    NaN
# 694  29/02/2024 22:00               NaN            NaN                    NaN
# 695  29/02/2024 23:00               NaN            NaN                    NaN
#
#      Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# 0                     3.0    44.0                        29.0
# 1                     2.0    45.0                        30.0
# 2                     2.0    47.0                        29.0
# 3                     2.0    47.0                        28.0
# 4                     2.0    48.0                        27.0
# ..                    ...     ...                         ...
# 691                   NaN     NaN                         NaN
# 692                   NaN     NaN                         NaN
# 693                   NaN     NaN                         NaN
# 694                   NaN     NaN                         NaN
# 695                   NaN     NaN                         NaN
#
#      Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# 0                           19.0                  0.2             2.4
# 1                           15.0                  0.2             2.6
# 2                           16.0                  0.2             2.5
# 3                           16.0                  0.2             2.2
# 4                           12.0                  0.2             2.2
# ..                           ...                  ...             ...
# 691                          NaN                  NaN             NaN
# 692                          NaN                  NaN             NaN
# 693                          NaN                  NaN             NaN
# 694                          NaN                  NaN             NaN
# 695                          NaN                  NaN             NaN
#
#      DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  Chuva  \
# 0            98.0         28.2    76.7        1003.3            0.0    0.0
# 1            98.4         28.1    75.2        1002.7            0.0    0.0
# 2           102.0         28.0    74.8        1002.2            0.0    0.0
# 3           102.2         28.0    75.4        1002.2            0.0    0.0
# 4            96.8         27.9    74.9        1002.2            0.0    0.0
# ..            ...          ...     ...           ...            ...    ...
# 691           NaN          NaN     NaN           NaN            NaN    NaN
# 692           NaN          NaN     NaN           NaN            NaN    NaN
# 693           NaN          NaN     NaN           NaN            NaN    NaN
# 694           NaN          NaN     NaN           NaN            NaN    NaN
# 695           NaN          NaN     NaN           NaN            NaN    NaN
#
#      chuva 24h
# 0          0.4
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 691        NaN
# 692        NaN
# 693        NaN
# 694        NaN
# 695        NaN
#
# [696 rows x 17 columns]

# %% [markdown]
# **5) Concatene os dois novos DataFrames em um único DataFrame chamado `fortaleza` de tal forma que os dados de fevereiro fique embaixo dos de janeiro. Não esqueça de resetar o índice (use `.reset_index(drop=True)`).**

# %%
fortaleza = pd.concat([janeiro_v1, fevereiro_v1]).reset_index(drop=True)

# Como os dados devem se parecer
fortaleza
# Out:
#                    MÊS  Óxido de Enxofre  Óxido Nítrico  \
# 0     01/01/2024 00:00              10.0            1.0
# 1     01/01/2024 01:00               7.0            1.0
# 2     01/01/2024 02:00               3.0            2.0
# 3     01/01/2024 03:00               4.0            2.0
# 4     01/01/2024 04:00               3.0            1.0
# ...                ...               ...            ...
# 1435  29/02/2024 19:00               NaN            NaN
# 1436  29/02/2024 20:00               NaN            NaN
# 1437  29/02/2024 21:00               NaN            NaN
# 1438  29/02/2024 22:00               NaN            NaN
# 1439  29/02/2024 23:00               NaN            NaN
#
#       Dióxido de Nitrogênio  Óxidos de Nitrogênio  Ozônio  \
# 0                       8.0                   9.0    21.0
# 1                       8.0                  10.0    20.0
# 2                      10.0                  12.0    18.0
# 3                      10.0                  13.0    15.0
# 4                       6.0                   7.0    46.0
# ...                     ...                   ...     ...
# 1435                    NaN                   NaN     NaN
# 1436                    NaN                   NaN     NaN
# 1437                    NaN                   NaN     NaN
# 1438                    NaN                   NaN     NaN
# 1439                    NaN                   NaN     NaN
#
#       Material Particulado <10µm  Material Particulado <2,5µm  \
# 0                           31.0                         18.0
# 1                           33.0                         22.0
# 2                           38.0                         15.0
# 3                           25.0                         20.0
# 4                           21.0                         18.0
# ...                          ...                          ...
# 1435                         NaN                          NaN
# 1436                         NaN                          NaN
# 1437                         NaN                          NaN
# 1438                         NaN                          NaN
# 1439                         NaN                          NaN
#
#       Monóxido de carbono  VelVento (m/s)  DirVento (°)  T-PM10 (°C)  UR (%)  \
# 0                     0.3             1.5           8.8         27.5    81.2
# 1                     0.4             0.9         342.9         27.4    82.6
# 2                     0.4             0.9           3.8         27.5    83.3
# 3                     0.4             0.5         308.9         27.0    88.8
# 4                     0.2             1.2          81.5         24.8    89.4
# ...                   ...             ...           ...          ...     ...
# 1435                  NaN             NaN           NaN          NaN     NaN
# 1436                  NaN             NaN           NaN          NaN     NaN
# 1437                  NaN             NaN           NaN          NaN     NaN
# 1438                  NaN             NaN           NaN          NaN     NaN
# 1439                  NaN             NaN           NaN          NaN     NaN
#
#       Press (mbar)  RadSol (W/m²)  Chuva  chuva 24h
# 0           1003.1            0.0    0.0       41.0
# 1           1002.9            0.0    0.0        NaN
# 2           1002.2            0.0    0.2        NaN
# 3           1002.0            0.0    0.0        NaN
# 4           1002.1            0.0   29.4        NaN
# ...            ...            ...    ...        ...
# 1435           NaN            NaN    NaN        NaN
# 1436           NaN            NaN    NaN        NaN
# 1437           NaN            NaN    NaN        NaN
# 1438           NaN            NaN    NaN        NaN
# 1439           NaN            NaN    NaN        NaN
#
# [1440 rows x 17 columns]

# %% [markdown]
# **6) Agora vamos começar a focar na informação de tempo. Qual é o tipo de dados dos objetos na coluna `MÊS`?**

# %%
fortaleza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MÊS                          1440 non-null   object
#  1   Óxido de Enxofre             1322 non-null   float64
#  2   Óxido Nítrico                1359 non-null   float64
#  3   Dióxido de Nitrogênio        1358 non-null   float64
#  4   Óxidos de Nitrogênio         1359 non-null   float64
#  5   Ozônio                       1360 non-null   float64
#  6   Material Particulado <10µm   1362 non-null   float64
#  7   Material Particulado <2,5µm  1361 non-null   float64
#  8   Monóxido de carbono          1302 non-null   float64
#  9   VelVento (m/s)               1344 non-null   float64
#  10  DirVento (°)                 1344 non-null   float64
#  11  T-PM10 (°C)                  1366 non-null   float64
#  12  UR (%)                       1344 non-null   float64
#  13  Press (mbar)                 1344 non-null   float64
#  14  RadSol (W/m²)                1344 non-null   float64
#  15  Chuva                        1342 non-null   float64
#  16  chuva 24h                    60 non-null     float64
# dtypes: float64(16), object(1)
# memory usage: 191.4+ KB

# %% [markdown]
# **7) Você deve ter visto que esses valores ainda são object. Use `pd.to_datetime` para converter essa coluna em objetos `datetime`.**
#
# **OBSERVAÇÃO** Não esqueça de usar `dayfirst=True`.

# %%
fortaleza["MÊS"] = pd.to_datetime(fortaleza["MÊS"], dayfirst=True)
fortaleza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MÊS                          1440 non-null   datetime64[ns]
#  1   Óxido de Enxofre             1322 non-null   float64
#  2   Óxido Nítrico                1359 non-null   float64
#  3   Dióxido de Nitrogênio        1358 non-null   float64
#  4   Óxidos de Nitrogênio         1359 non-null   float64
#  5   Ozônio                       1360 non-null   float64
#  6   Material Particulado <10µm   1362 non-null   float64
#  7   Material Particulado <2,5µm  1361 non-null   float64
#  8   Monóxido de carbono          1302 non-null   float64
#  9   VelVento (m/s)               1344 non-null   float64
#  10  DirVento (°)                 1344 non-null   float64
#  11  T-PM10 (°C)                  1366 non-null   float64
#  12  UR (%)                       1344 non-null   float64
#  13  Press (mbar)                 1344 non-null   float64
#  14  RadSol (W/m²)                1344 non-null   float64
#  15  Chuva                        1342 non-null   float64
#  16  chuva 24h                    60 non-null     float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 191.4 KB

# %% [markdown]
# **8) Agora que a coluna `MÊS` são realmente objetos `datetime`. Faça o seguinte:**
#
# - use `.dt.month` para criar uma nova coluna chama `Mês` (desse jeito) e use `.dt.date` para criar a coluna `Data`.
#
# - use `.replace()` para substituir o 1 pela string `"Janeiro"` e 2 pela string `"Fevereiro"` nessa coluna `Mês`.
#
# - Descarte a coluna `"MÊS"` do DataFrame `fortaleza`.

# %%
# Primeiro passo
fortaleza["Mês"] = fortaleza["MÊS"].dt.month
fortaleza["Data"] = fortaleza["MÊS"].dt.date

# Segundo passo
fortaleza["Mês"] = fortaleza["Mês"].replace({1: "Janeiro", 2: "Fevereiro"})

# Terceiro passo
fortaleza = fortaleza.drop("MÊS", axis=1)

# Veja como deve ficar:
fortaleza
# Out:
#       Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# 0                 10.0            1.0                    8.0
# 1                  7.0            1.0                    8.0
# 2                  3.0            2.0                   10.0
# 3                  4.0            2.0                   10.0
# 4                  3.0            1.0                    6.0
# ...                ...            ...                    ...
# 1435               NaN            NaN                    NaN
# 1436               NaN            NaN                    NaN
# 1437               NaN            NaN                    NaN
# 1438               NaN            NaN                    NaN
# 1439               NaN            NaN                    NaN
#
#       Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# 0                      9.0    21.0                        31.0
# 1                     10.0    20.0                        33.0
# 2                     12.0    18.0                        38.0
# 3                     13.0    15.0                        25.0
# 4                      7.0    46.0                        21.0
# ...                    ...     ...                         ...
# 1435                   NaN     NaN                         NaN
# 1436                   NaN     NaN                         NaN
# 1437                   NaN     NaN                         NaN
# 1438                   NaN     NaN                         NaN
# 1439                   NaN     NaN                         NaN
#
#       Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# 0                            18.0                  0.3             1.5
# 1                            22.0                  0.4             0.9
# 2                            15.0                  0.4             0.9
# 3                            20.0                  0.4             0.5
# 4                            18.0                  0.2             1.2
# ...                           ...                  ...             ...
# 1435                          NaN                  NaN             NaN
# 1436                          NaN                  NaN             NaN
# 1437                          NaN                  NaN             NaN
# 1438                          NaN                  NaN             NaN
# 1439                          NaN                  NaN             NaN
#
#       DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  Chuva  \
# 0              8.8         27.5    81.2        1003.1            0.0    0.0
# 1            342.9         27.4    82.6        1002.9            0.0    0.0
# 2              3.8         27.5    83.3        1002.2            0.0    0.2
# 3            308.9         27.0    88.8        1002.0            0.0    0.0
# 4             81.5         24.8    89.4        1002.1            0.0   29.4
# ...            ...          ...     ...           ...            ...    ...
# 1435           NaN          NaN     NaN           NaN            NaN    NaN
# 1436           NaN          NaN     NaN           NaN            NaN    NaN
# 1437           NaN          NaN     NaN           NaN            NaN    NaN
# 1438           NaN          NaN     NaN           NaN            NaN    NaN
# 1439           NaN          NaN     NaN           NaN            NaN    NaN
#
#       chuva 24h        Mês        Data
# 0          41.0    Janeiro  2024-01-01
# 1           NaN    Janeiro  2024-01-01
# 2           NaN    Janeiro  2024-01-01
# 3           NaN    Janeiro  2024-01-01
# 4           NaN    Janeiro  2024-01-01
# ...         ...        ...         ...
# 1435        NaN  Fevereiro  2024-02-29
# 1436        NaN  Fevereiro  2024-02-29
# 1437        NaN  Fevereiro  2024-02-29
# 1438        NaN  Fevereiro  2024-02-29
# 1439        NaN  Fevereiro  2024-02-29
#
# [1440 rows x 18 columns]

# %% [markdown]
# **9) Agora agrupe por esta coluna `Data` usando `.groupby()` com o agregado `mean(numeric_only=True)` e salve em uma variável chamada `por_data`:**

# %%
por_data = fortaleza.groupby("Data").mean(numeric_only=True)

# Como deve parecer o por_data.head()
por_data.head()
# Out:
#             Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# Data
# 2024-01-01          3.958333       2.208333               9.791667
# 2024-01-02          8.833333       5.416667               8.291667
# 2024-01-03          5.875000       2.000000               6.250000
# 2024-01-04          7.958333       1.250000               4.708333
# 2024-01-05          8.666667       2.541667               5.875000
#
#             Óxidos de Nitrogênio     Ozônio  Material Particulado <10µm  \
# Data
# 2024-01-01             13.041667  29.833333                   26.583333
# 2024-01-02             16.791667  20.666667                   30.083333
# 2024-01-03              9.250000  24.541667                   23.375000
# 2024-01-04              6.791667  29.291667                   23.125000
# 2024-01-05              9.791667  25.916667                   30.583333
#
#             Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# Data
# 2024-01-01                    17.791667             0.337500        1.064706
# 2024-01-02                    18.916667             0.316667        2.022222
# 2024-01-03                    14.041667             0.245833        2.004167
# 2024-01-04                    12.041667             0.225000        2.500000
# 2024-01-05                    16.833333             0.237500        2.341667
#
#             DirVento (°)  T-PM10 (°C)     UR (%)  Press (mbar)  RadSol (W/m²)  \
# Data
# 2024-01-01    150.417647    26.141667  87.611765   1003.152941      91.117647
# 2024-01-02     82.511111    27.516667  79.600000   1001.888889      68.111111
# 2024-01-03     97.308333    27.954167  78.733333   1002.987500     259.833333
# 2024-01-04     92.766667    28.237500  75.508333   1002.441667     291.208333
# 2024-01-05    112.541667    28.091667  75.150000   1001.416667     275.708333
#
#                Chuva  chuva 24h
# Data
# 2024-01-01  2.411765       41.0
# 2024-01-02  0.000000        0.0
# 2024-01-03  0.204167        4.9
# 2024-01-04  0.016667        0.4
# 2024-01-05  0.000000        0.0

# %% [markdown]
# **9) Usando esse dataframe `por_data` plote a média desses gases do efeito estufa: `gases = ["Óxido de Enxofre", "Óxido Nítrico", "Dióxido de Nitrogênio", "Óxidos de Nitrogênio", "Ozônio"]`. Faça uma análise discutiva do que você vê.**

# %%
gases = ["Óxido de Enxofre", "Óxido Nítrico", "Dióxido de Nitrogênio", "Óxidos de Nitrogênio", "Ozônio"]
por_data[gases].plot(figsize=(12, 6));

# %% [markdown]
# **10) Usando a seleção condicional que aprendemos nesse dataframe `por_data`, responda às seguintes perguntas:**
#
# 1. Em qual dia a média de Óxidos de Nitrogênio foi a mais alta? Esse resultado bate com o gráfico?
#
# 2. Em qual dia a média de Ozônio foi a mais baixa? Esse resultado bate com o gráfico?
#
# 3. Qual era a qualidade do ar no dia mais chuvoso em Fortaleza?
#
# 4. Quais foram os dias em que houve chuva durante 24 horas? Coloque em ordem da maior média para a menor.

# %%
# Em qual dia a média de Óxidos de Nitrogênio foi a mais alta?
por_data[por_data["Óxidos de Nitrogênio"] == por_data["Óxidos de Nitrogênio"].max()]
# Out:
#             Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# Data
# 2024-02-23         11.217391        7.26087              17.913043
#
#             Óxidos de Nitrogênio     Ozônio  Material Particulado <10µm  \
# Data
# 2024-02-23             29.130435  16.478261                        33.0
#
#             Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# Data
# 2024-02-23                    15.869565             0.521739        0.783333
#
#             DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  \
# Data
# 2024-02-23    160.441667       26.125    89.9   1003.308333      93.458333
#
#                Chuva  chuva 24h
# Data
# 2024-02-23  0.756522       17.4

# %%
# Em qual dia a média de Ozônio foi a mais baixa?
por_data[por_data["Ozônio"] == por_data["Ozônio"].min()]
# Out:
#             Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# Data
# 2024-02-29              10.0            2.0                   11.8
#
#             Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# Data
# 2024-02-29                  15.4    11.6                        26.6
#
#             Material Particulado <2,5µm  Monóxido de carbono  VelVento (m/s)  \
# Data
# 2024-02-29                         11.0                 0.32            0.62
#
#             DirVento (°)  T-PM10 (°C)  UR (%)  Press (mbar)  RadSol (W/m²)  \
# Data
# 2024-02-29        273.56        24.92   90.82       1003.52            0.0
#
#             Chuva  chuva 24h
# Data
# 2024-02-29    0.0        0.0

# %%
# Qual era a qualidade do ar no dia mais chuvoso em Fortaleza?
por_data[por_data["Chuva"] == por_data["Chuva"].max()]
# Out:
#             Óxido de Enxofre  Óxido Nítrico  Dióxido de Nitrogênio  \
# Data
# 2024-02-10         11.208333            2.0              12.333333
#
#             Óxidos de Nitrogênio  Ozônio  Material Particulado <10µm  \
# Data
# 2024-02-10             15.333333  28.375                   48.916667
